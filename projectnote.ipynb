# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20211108040203-0001
# KERNEL_ID = 5434cd81-4424-4a28-a082-0a6f0480f4bb
# [Row(CSD='1', BORO='M', GRADE ='0K', PROGRAM TYPE='GEN ED', CORE SUBJECT (MS CORE and 9-12 ONLY)='-', CORE COURSE (MS CORE and 9-12 ONLY)='-', SERVICE CATEGORY(K-9* ONLY)='-', NUMBER OF STUDENTS / SEATS FILLED='792', NUMBER OF SECTIONS='39', AVERAGE CLASS SIZE='20.3'),
#  Row(CSD='1', BORO='M', GRADE ='0K', PROGRAM TYPE='CTT', CORE SUBJECT (MS CORE and 9-12 ONLY)='-', CORE COURSE (MS CORE and 9-12 ONLY)='-', SERVICE CATEGORY(K-9* ONLY)='-', NUMBER OF STUDENTS / SEATS FILLED='187', NUMBER OF SECTIONS='9', AVERAGE CLASS SIZE='20.8'),
#  Row(CSD='1', BORO='M', GRADE ='01', PROGRAM TYPE='GEN ED', CORE SUBJECT (MS CORE and 9-12 ONLY)='-', CORE COURSE (MS CORE and 9-12 ONLY)='-', SERVICE CATEGORY(K-9* ONLY)='-', NUMBER OF STUDENTS / SEATS FILLED='662', NUMBER OF SECTIONS='33', AVERAGE CLASS SIZE='20.1'),
# ...
